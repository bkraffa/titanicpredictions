# %%
#Imports for data analysis, data wrangling and visualization
import pandas as pd
import numpy as np
import random as rand
import seaborn as sns
import matplotlib.pyplot as plt

#Machine learning imports
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC,LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron, SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
#Loading the data
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')
combine = [train_df,test_df]

# %%
#Checking the column names
print(train_df.columns.values)

#Categorical variables - Survived, Sex, Embarked, Pclass
#Numerical variables - Age, Fare, SibSP, Parch
#Ticket is a mix of numeric and alphanumeric data types and Cabin is Alphanumeric
# Out:
# ['PassengerId' 'Survived' 'Pclass' 'Name' 'Sex' 'Age' 'SibSp' 'Parch'
#  'Ticket' 'Fare' 'Cabin' 'Embarked']

# %%
#Checking the training DF
train_df.tail(15)
#Cabin and Age contain null values
# Out:
#      PassengerId  Survived  Pclass  \
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                               Name     Sex   Age  SibSp  \
# 876                  Gustafsson, Mr. Alfred Ossian    male  20.0      0
# 877                           Petroff, Mr. Nedelio    male  19.0      0
# 878                             Laleff, Mr. Kristo    male   NaN      0
# 879  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880   Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 881                             Markun, Mr. Johann    male  33.0      0
# 882                   Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 883                  Banfield, Mr. Frederick James    male  28.0      0
# 884                         Sutehall, Mr. Henry Jr    male  25.0      0
# 885           Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                          Montvila, Rev. Juozas    male  27.0      0
# 887                   Graham, Miss. Margaret Edith  female  19.0      0
# 888       Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                          Behr, Mr. Karl Howell    male  26.0      0
# 890                            Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 876      0              7534   9.8458   NaN        S
# 877      0            349212   7.8958   NaN        S
# 878      0            349217   7.8958   NaN        S
# 879      1             11767  83.1583   C50        C
# 880      1            230433  26.0000   NaN        S
# 881      0            349257   7.8958   NaN        S
# 882      0              7552  10.5167   NaN        S
# 883      0  C.A./SOTON 34068  10.5000   NaN        S
# 884      0   SOTON/OQ 392076   7.0500   NaN        S
# 885      5            382652  29.1250   NaN        Q
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q

# %%
#Checking the test DF
test_df.tail(15)
#Cabin and Age contain null values
# Out:
#      PassengerId  Pclass                                             Name  \
# 403         1295       1                           Carrau, Mr. Jose Pedro
# 404         1296       1                     Frauenthal, Mr. Isaac Gerald
# 405         1297       2     Nourney, Mr. Alfred (Baron von Drachstedt")"
# 406         1298       2                        Ware, Mr. William Jeffery
# 407         1299       1                       Widener, Mr. George Dunton
# 408         1300       3                  Riordan, Miss. Johanna Hannah""
# 409         1301       3                        Peacock, Miss. Treasteall
# 410         1302       3                           Naughton, Miss. Hannah
# 411         1303       1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 412         1304       3                   Henriksson, Miss. Jenny Lovisa
# 413         1305       3                               Spector, Mr. Woolf
# 414         1306       1                     Oliva y Ocana, Dona. Fermina
# 415         1307       3                     Saether, Mr. Simon Sivertsen
# 416         1308       3                              Ware, Mr. Frederick
# 417         1309       3                         Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 403    male  17.0      0      0              113059   47.1000   NaN        S
# 404    male  43.0      1      0               17765   27.7208   D40        C
# 405    male  20.0      0      0       SC/PARIS 2166   13.8625   D38        C
# 406    male  23.0      1      0               28666   10.5000   NaN        S
# 407    male  50.0      1      1              113503  211.5000   C80        C
# 408  female   NaN      0      0              334915    7.7208   NaN        Q
# 409  female   3.0      1      1  SOTON/O.Q. 3101315   13.7750   NaN        S
# 410  female   NaN      0      0              365237    7.7500   NaN        Q
# 411  female  37.0      1      0               19928   90.0000   C78        Q
# 412  female  28.0      0      0              347086    7.7750   NaN        S
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C

# %%
#Checking the data types of the features (7 features are integers or floats (6 in test), 5 features are strings)
train_df.info()
print('-'*40)
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# ----------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
#Checking the numerical distribution of numerical features across the samples
train_df.describe()
#891 samples of 2224 that were aboard
#Around 38% survived, compared to 32% of the actual rate
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_df.describe(include=['O'])
# Names are unique
# 65% are male (577/891)
# A lot of the cabins are shared (147 cabins), also duplicate values
# 3 possible embarked values, S is the most popular (644/889)
# Ticket feature has a high ratio of duplicate values (681/891)
# Out:
#                                 Name   Sex    Ticket Cabin Embarked
# count                            891   891       891   204      889
# unique                           891     2       681   147        3
# top     Williams, Mr. Charles Eugene  male  CA. 2343    G6        S
# freq                               1   577         7     4      644

# %% [markdown]
# Assumptions based on the data analysis so far:
# ------

# %% [markdown]
# 1) Correlating: We need to know how each of the features correlate with survival.

# %% [markdown]
# 2) Completing: We need to complete the age and embarked features as they are probably related to survival.

# %% [markdown]
# 3) Correcting: Ticket (high ratio of duplicates), Cabin (highly incomplete with many missing values) and passangerID (does not contribute to survival) should be dropped

# %% [markdown]
# 4) Creating: We may need to create a new feature called 'Family' based on Parch and SibSp to get total count of family members. We may want to manipulate the name feature to extract title as a new feature. We may want to group age into bands as this turns the numerical feature into an ordinal categorical feature. We may also want to create a fare range to see if it correlates with survival.

# %% [markdown]
# 5) Classifying: Based on the problem description we can check for some assumptions -> Woman (sex=female), Children and Upper Class Passengers (pclass=1) are more likely to have survived

# %%
#To confirm some of our assumptions we can analyze feature correlation by pivoting features against each other
train_df[['Pclass','Survived']].groupby(['Pclass'], as_index = False).mean().sort_values(by=['Survived'], ascending = False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
train_df[['Sex','Survived']].groupby(['Sex'], as_index = False).mean().sort_values(by=['Survived'], ascending = False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
train_df[['SibSp','Survived']].groupby(['SibSp'], as_index = False).mean().sort_values(by=['Survived'], ascending = False)
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
train_df[['Parch','Survived']].groupby(['Parch'], as_index = False).mean().sort_values(by=['Survived'], ascending = False)
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %% [markdown]
# Analyze by visualizing data
# ---

# %% [markdown]
# 1) Correlating Numerical Features
# ----

# %%
graph = sns.FacetGrid(train_df,col = 'Survived')
graph.map(plt.hist, 'Age', bins = 20)

# %% [markdown]
# Observations:
# ----

# %% [markdown]
#         1) Babies (age<4) had a high survival rate
#         2) Oldest passanger survived (age=80)
#         3) A lot with passangers age 15 to 25 did not survived
#         4) Most passangers are in the 15-35 age range

# %% [markdown]
# Decisions
# ---

# %% [markdown]
#         1) We should consider age in our model training
#         2) We should complete the age feature for null values
#         3) We should band age groups to perform a better analysis

# %% [markdown]
# 2) Correlating Numerical and Ordinal Features
# ---

# %%
graph = sns.FacetGrid(train_df, col = 'Survived',row='Pclass')
graph.map(plt.hist, 'Age', bins = 20)
graph.add_legend()

# %% [markdown]
# Observations:
# ----

# %% [markdown]
#         1) Pclass=3 had the higher number of passangers but most of them didnt survive
#         2) Babies in pclass = 2 and 3 mostly survived so it further qualifies our assumption about it
#         3) Most passengers in pclass = 1 survived
#         4) Pclass varies in terms of age distribution

# %% [markdown]
# Decisions:
# ---

# %% [markdown]
#         1) Consider pclass for training

# %% [markdown]
# 3)  Correlating Categorical Features
# ---

# %%
graph = sns.FacetGrid(train_df, row = 'Embarked')
graph.map(sns.pointplot, 'Pclass','Survived','Sex')
graph.add_legend()
# Out:
# C:\Users\bruno\anaconda3\lib\site-packages\seaborn\axisgrid.py:643: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# C:\Users\bruno\anaconda3\lib\site-packages\seaborn\axisgrid.py:648: UserWarning: Using the pointplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# Observations:
# ----

# %% [markdown]
#         1) Female passengers had a much better survival rate
#         2) Exception is embarked = C where males had a higher survival rate
#         3) Males had a higher survival rate in pclass=3 when compared do pclass=2 for C and Q ports

# %% [markdown]
# Decisions:
# ----

# %% [markdown]
#         1) Add sex feature to the model training
#         2) Complete and add embarked feature to the model training

# %% [markdown]
# 4)  Correlating Categorical and Numerical Features
# ---

# %%
graph = sns.FacetGrid(train_df, col = 'Survived',row='Embarked')
graph.map(sns.barplot, 'Sex','Fare', ci = None)
graph.add_legend()
# Out:
# C:\Users\bruno\anaconda3\lib\site-packages\seaborn\axisgrid.py:643: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# Observations:
# ----

# %% [markdown]
#         1) Higher fare rates had higher survival rates
#         2) Port of embarkation correlates with the survival rates

# %% [markdown]
# Decisions:
# ----

# %% [markdown]
#         1) We should band the fare rates and consider them in the model

# %% [markdown]
# Wrangle the data
# ---

# %%
#dropping unnecessary features to speed up the training
IDs = test_df['PassengerId']
train_df.drop(['Ticket','Cabin','PassengerId'], inplace=True, axis = 1)
test_df.drop(['Ticket','Cabin','PassengerId'], inplace=True, axis = 1)
combine = [train_df,test_df]

# %%
#creating new feature from existing - 'name' - extracting the characters of the string until the first space on the feature name
for dataset in combine:
    dataset['Title'] = dataset.Name.str.extract('([A-Za-z]+)\.', expand = False)

pd.crosstab(train_df['Title'], train_df['Sex'])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
#we can group the uncommon titles on a category named other
for dataset in combine:
    dataset['Title'] = dataset['Title'].replace(['Lady', 'Countess','Capt', 'Col',\
 	'Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Other')
    dataset['Title'] = dataset['Title'].replace('Mlle','Miss')
    dataset['Title'] = dataset['Title'].replace('Ms','Miss')
    dataset['Title'] = dataset['Title'].replace('Mme','Mrs')

train_df.groupby('Title').mean()
# Out:
#         Survived    Pclass        Age     SibSp     Parch       Fare
# Title
# Master  0.575000  2.625000   4.574167  2.300000  1.375000  34.703125
# Miss    0.702703  2.291892  21.845638  0.702703  0.540541  43.800092
# Mr      0.156673  2.410058  32.368090  0.288201  0.152805  24.441560
# Mrs     0.793651  1.992063  35.788991  0.690476  0.825397  45.330290
# Other   0.347826  1.347826  45.545455  0.347826  0.086957  37.169748

# %%
#Then we can convert the categorical titles to ordinal
title_dict = {'Mr': 1,
            'Miss': 2,
            'Mrs': 3,
            'Master': 4,
            'Other': 5 }
for dataset in combine:
    dataset['Title'] = dataset['Title'].map(title_dict) 
    dataset['Title'] = dataset['Title'].fillna(0)

train_df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Embarked  Title
# 0    male  22.0      1      0   7.2500        S      1
# 1  female  38.0      1      0  71.2833        C      3
# 2  female  26.0      0      0   7.9250        S      2
# 3  female  35.0      1      0  53.1000        S      3
# 4    male  35.0      0      0   8.0500        S      1

# %%
#now we can also drop the name feature
train_df.drop(['Name'], axis = 1 , inplace = True)
train_df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  Title
# 0         0       3    male  22.0      1      0   7.2500        S      1
# 1         1       1  female  38.0      1      0  71.2833        C      3
# 2         1       3  female  26.0      0      0   7.9250        S      2
# 3         1       1  female  35.0      1      0  53.1000        S      3
# 4         0       3    male  35.0      0      0   8.0500        S      1

# %%
#converting the categorical feature (sex) into ordinal
for dataset in combine:
    dataset['Sex'] = dataset['Sex'].map({'female':1,
                                        'male':0})
train_df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked  Title
# 0         0       3    0  22.0      1      0   7.2500        S      1
# 1         1       1    1  38.0      1      0  71.2833        C      3
# 2         1       3    1  26.0      0      0   7.9250        S      2
# 3         1       1    1  35.0      1      0  53.1000        S      3
# 4         0       3    0  35.0      0      0   8.0500        S      1

# %%
#now we should estimate or complete the feature with missing or null values, we'll start with the Age feature
#we will guess the missing values for age by using other correlated features like gender and pclass
graph = sns.FacetGrid(train_df, row = 'Pclass', col = 'Sex')
graph.map(plt.hist, 'Age', bins = 20)
graph.add_legend()

# %%
#Lets prepare an empty array to contain the guessed age values for all the 6 pclass x gender combinations
guess_ages = np.zeros((2,3))
guess_ages
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
#Now we iterate to get the median of each combination of pclass and sex, and use it to fill the missing value for each combination

for dataset in combine:
    for i in range (0,2):
        for j in range(0,3):
           guess_df = dataset[(dataset['Sex'] == i) & \
                                  (dataset['Pclass'] == j+1)]['Age'].dropna()
           age_guess = guess_df.median()
           guess_ages[i,j] = int(age_guess/.5 +.5)*.5 #convert random age float to nearest .5 age

    for i in range (0,2):
        for j in range (0,3):
            dataset.loc[ (dataset.Age.isnull()) & (dataset.Sex == i) & (dataset.Pclass == j+1),\
                    'Age'] = guess_ages[i,j]

    dataset['Age'] = dataset['Age'].astype(int)

train_df.head()
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare Embarked  Title
# 0         0       3    0   22      1      0   7.2500        S      1
# 1         1       1    1   38      1      0  71.2833        C      3
# 2         1       3    1   26      0      0   7.9250        S      2
# 3         1       1    1   35      1      0  53.1000        S      3
# 4         0       3    0   35      0      0   8.0500        S      1

# %%
#Checking to see how the ages split in 5 different bands (in absolut numbers not amount)
train_df['AgeBand'] = pd.cut(train_df['Age'],5)
train_df[['AgeBand','Survived']].groupby(['AgeBand'], as_index = False).mean().sort_values(by='AgeBand', ascending=True)
# Out:
#          AgeBand  Survived
# 0  (-0.08, 16.0]  0.550000
# 1   (16.0, 32.0]  0.337374
# 2   (32.0, 48.0]  0.412037
# 3   (48.0, 64.0]  0.434783
# 4   (64.0, 80.0]  0.090909

# %%
#Attributing a number to each of the agebands
for dataset in combine:
    dataset.loc[dataset['Age'] <= 16,'Age'] = 0
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 32),'Age'] = 1
    dataset.loc[(dataset['Age'] > 32) & (dataset['Age'] <= 48),'Age'] = 2
    dataset.loc[(dataset['Age'] > 48) & (dataset['Age'] <= 64),'Age'] = 3
    dataset.loc[dataset['Age'] > 64,'Age'] = 4
train_df.head()
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare Embarked  Title  \
# 0         0       3    0    1      1      0   7.2500        S      1
# 1         1       1    1    2      1      0  71.2833        C      3
# 2         1       3    1    1      0      0   7.9250        S      2
# 3         1       1    1    2      1      0  53.1000        S      3
# 4         0       3    0    2      0      0   8.0500        S      1
#
#         AgeBand
# 0  (16.0, 32.0]
# 1  (32.0, 48.0]
# 2  (16.0, 32.0]
# 3  (32.0, 48.0]
# 4  (32.0, 48.0]

# %%
train_df.drop(columns='AgeBand', inplace =True, axis = 1)
combine = [train_df,test_df]
train_df
# Out:
#      Survived  Pclass  Sex  Age  SibSp  Parch     Fare Embarked  Title
# 0           0       3    0    1      1      0   7.2500        S      1
# 1           1       1    1    2      1      0  71.2833        C      3
# 2           1       3    1    1      0      0   7.9250        S      2
# 3           1       1    1    2      1      0  53.1000        S      3
# 4           0       3    0    2      0      0   8.0500        S      1
# ..        ...     ...  ...  ...    ...    ...      ...      ...    ...
# 886         0       2    0    1      0      0  13.0000        S      5
# 887         1       1    1    1      0      0  30.0000        S      2
# 888         0       3    1    1      1      2  23.4500        S      2
# 889         1       1    0    1      0      0  30.0000        C      1
# 890         0       3    0    1      0      0   7.7500        Q      1
#
# [891 rows x 9 columns]

# %%
#Here we are aggregating the number of partners (parch) with simblings (SibSp) and the person itself (+1) to create a feature with the total number of members of the same family
for dataset in combine:
    dataset['FamilySize'] = dataset['Parch'] + dataset['SibSp'] + 1 
    dataset.drop(columns=['SibSp','Parch'],inplace=True,axis=1)    
train_df[['FamilySize','Survived']].groupby(['FamilySize'], as_index=False).mean().sort_values(by=['Survived'],ascending = False)
# Out:
#    FamilySize  Survived
# 3           4  0.724138
# 2           3  0.578431
# 1           2  0.552795
# 6           7  0.333333
# 0           1  0.303538
# 4           5  0.200000
# 5           6  0.136364
# 7           8  0.000000
# 8          11  0.000000

# %%
#Creating a feature 'isAlone' will help us to correlate the fact of being alone with the chance of surviving
for dataset in combine:
    dataset['isAlone'] = 0
    dataset.loc[dataset['FamilySize'] == 1, 'isAlone'] = 1
    dataset.drop('FamilySize',inplace=True,axis=1) #we can also drop family size as we've created isAlone
train_df[['isAlone','Survived']].groupby(['isAlone']).mean().sort_values(by=['Survived'],ascending=False)
#Its possible to see that the alone people had a higher survival mean rate
# Out:
#          Survived
# isAlone
# 0        0.505650
# 1        0.303538

# %%
#We can create a new feature multiplying age and the pclass, so in theory the lower number would be the people with the younger age and higher class 
for dataset in combine:
    dataset['AgeClass'] = dataset['Age'] * dataset['Pclass']

train_df[['Age','Pclass','AgeClass']].head(10)
# Out:
#    Age  Pclass  AgeClass
# 0    1       3         3
# 1    2       1         2
# 2    1       3         3
# 3    2       1         2
# 4    2       3         6
# 5    1       3         3
# 6    3       1         3
# 7    0       3         0
# 8    1       3         3
# 9    0       2         0

# %%
#Checking the embarked feature we can see that S is the most common port, so we'll apply it to the two missing values of the column
train_df.Embarked.describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %%
freq_port = 'S'
for dataset in combine:
    dataset['Embarked'].fillna(freq_port,inplace=True)
train_df[['Embarked','Survived']].groupby(['Embarked']).mean().sort_values(by=['Survived'],ascending=True)
#Its possible to see that the S port had the lower mean survival rate and C had the higher
# Out:
#           Survived
# Embarked
# S         0.339009
# Q         0.389610
# C         0.553571

# %%
#Mapping the ports
for dataset in combine:
    dataset['Embarked'] = dataset['Embarked'].map({'S':0,
    'C':1,
    'Q':2}).astype(int)
train_df.head(10)
# Out:
#    Survived  Pclass  Sex  Age     Fare  Embarked  Title  isAlone  AgeClass
# 0         0       3    0    1   7.2500         0      1        0         3
# 1         1       1    1    2  71.2833         1      3        0         2
# 2         1       3    1    1   7.9250         0      2        1         3
# 3         1       1    1    2  53.1000         0      3        0         2
# 4         0       3    0    2   8.0500         0      1        1         6
# 5         0       3    0    1   8.4583         2      1        1         3
# 6         0       1    0    3  51.8625         0      1        1         3
# 7         0       3    0    0  21.0750         0      4        0         0
# 8         1       3    1    1  11.1333         0      3        0         3
# 9         1       2    1    0  30.0708         1      3        0         0

# %%
#Complete fare for the single missing value on the test DF using the mode
test_df['Fare'].fillna(test_df['Fare'].dropna().median(),inplace=True)
test_df
# Out:
#      Pclass                                          Name  Sex  Age      Fare  \
# 0         3                              Kelly, Mr. James    0    2    7.8292
# 1         3              Wilkes, Mrs. James (Ellen Needs)    1    2    7.0000
# 2         2                     Myles, Mr. Thomas Francis    0    3    9.6875
# 3         3                              Wirz, Mr. Albert    0    1    8.6625
# 4         3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1    1   12.2875
# ..      ...                                           ...  ...  ...       ...
# 413       3                            Spector, Mr. Woolf    0    1    8.0500
# 414       1                  Oliva y Ocana, Dona. Fermina    1    2  108.9000
# 415       3                  Saether, Mr. Simon Sivertsen    0    2    7.2500
# 416       3                           Ware, Mr. Frederick    0    1    8.0500
# 417       3                      Peter, Master. Michael J    0    1   22.3583
#
#      Embarked  Title  isAlone  AgeClass
# 0           2      1        1         6
# 1           0      3        0         6
# 2           2      1        1         6
# 3           0      1        1         3
# 4           0      3        0         3
# ..        ...    ...      ...       ...
# 413         0      1        1         3
# 414         1      5        1         2
# 415         0      1        1         6
# 416         0      1        1         3
# 417         1      4        0         3
#
# [418 rows x 9 columns]

# %%
#We can now create the bands for the fare, but as we did for the age we have to check the bands before
train_df['FareBand'] = pd.qcut(train_df['Fare'],4) #qcut divides into 4 quantiles for the bands
train_df[['FareBand','Survived']].groupby(['FareBand'],as_index=False).mean().sort_values(by=['FareBand'],ascending=True)
#We can see that the higher the band the higher the survival mean rate
# Out:
#           FareBand  Survived
# 0   (-0.001, 7.91]  0.197309
# 1   (7.91, 14.454]  0.303571
# 2   (14.454, 31.0]  0.454955
# 3  (31.0, 512.329]  0.581081

# %%
for dataset in combine:
    dataset.loc[ dataset['Fare'] <= 7.91, 'Fare'] = 0
    dataset.loc[(dataset['Fare'] > 7.91) & (dataset['Fare'] <= 14.454), 'Fare'] = 1
    dataset.loc[(dataset['Fare'] > 14.454) & (dataset['Fare'] <= 31), 'Fare']  = 2
    dataset.loc[ dataset['Fare'] > 31, 'Fare'] = 3
    dataset['Fare'] = dataset['Fare'].astype(int)

train_df.drop(['FareBand'], axis=1, inplace=True)
combine = [train_df, test_df]
    
train_df
# Out:
#      Survived  Pclass  Sex  Age  Fare  Embarked  Title  isAlone  AgeClass
# 0           0       3    0    1     0         0      1        0         3
# 1           1       1    1    2     3         1      3        0         2
# 2           1       3    1    1     1         0      2        1         3
# 3           1       1    1    2     3         0      3        0         2
# 4           0       3    0    2     1         0      1        1         6
# ..        ...     ...  ...  ...   ...       ...    ...      ...       ...
# 886         0       2    0    1     1         0      5        1         2
# 887         1       1    1    1     2         0      2        1         1
# 888         0       3    1    1     2         0      2        0         3
# 889         1       1    0    1     2         1      1        1         1
# 890         0       3    0    1     0         2      1        1         3
#
# [891 rows x 9 columns]

# %%
#And now both our datasets are ready
test_df.drop(columns=['Name'],inplace=True,axis=1)
test_df.head(100)
# Out:
#     Pclass  Sex  Age  Fare  Embarked  Title  isAlone  AgeClass
# 0        3    0    2     0         2      1        1         6
# 1        3    1    2     0         0      3        0         6
# 2        2    0    3     1         2      1        1         6
# 3        3    0    1     1         0      1        1         3
# 4        3    1    1     1         0      3        0         3
# ..     ...  ...  ...   ...       ...    ...      ...       ...
# 95       3    0    1     0         0      1        1         3
# 96       1    1    4     3         0      3        0         4
# 97       3    0    1     1         0      1        1         3
# 98       3    1    1     0         0      2        1         3
# 99       3    0    2     1         0      1        1         6
#
# [100 rows x 8 columns]

# %% [markdown]
# Model, Predictions and Solution
# -----

# %% [markdown]
# - Our problem is a classification and regression problem. We wanna identify the relationship between the output (survived yes or no) and the other variables
# - We are performing supervised learning as we'll train our model based on a given dataset
# - Therefore we have two main criteria for our algoritm picking: Supervised Learning and Classification/Regression Problem

# %% [markdown]
# Some of the models we can use:
# * Logistic Regression
# * K-Nearest Neighbors (KNN)
# * Support Vector Machines
# * Naive Bayes Classifier
# * Decision Tree
# * Random Forest
# * Perceptron
# * Artifical Neural Network
# * Relevance Vector Machine (RVM)

# %%
X_train = train_df.drop('Survived',axis=1)
Y_train = train_df['Survived']
X_test = test_df.copy()
X_train.shape,Y_train.shape,X_test.shape
# Out:
# ((891, 8), (891,), (418, 8))

# %%
#Logistic Regression
logreg = LogisticRegression()
logreg.fit(X_train,Y_train)
Y_pred = logreg.predict(X_test)
acc_log = round(logreg.score(X_train,Y_train) * 100,2)
print(acc_log,'%')
# Out:
# 81.37 %

# %%
coeff = pd.DataFrame(train_df.columns.delete(0))
coeff.columns = ['Feature']
coeff['Correlation'] = pd.Series(logreg.coef_[0])
coeff.sort_values(by = 'Correlation', ascending = False)
# Out:
#     Feature  Correlation
# 1       Sex     2.201057
# 5     Title     0.406027
# 4  Embarked     0.276628
# 6   isAlone     0.185986
# 7  AgeClass    -0.050260
# 3      Fare    -0.071665
# 2       Age    -0.469638
# 0    Pclass    -1.200309

# %%
#Support Vector Machines
for i in range (0,20):
    svc = SVC(kernel = 'poly',degree=i)
    svc.fit(X_train,Y_train)
    Y_pred = svc.predict(X_test)
    acc_svc = round(svc.score(X_train,Y_train) * 100,2)
    print(acc_svc,'%','--',i)


svc = SVC(kernel = 'poly',degree=14)
svc.fit(X_train,Y_train)
Y_pred = svc.predict(X_test)
acc_svc = round(svc.score(X_train,Y_train) * 100,2)
# Out:
# 61.62 % -- 0
# 78.68 % -- 1
# 80.25 % -- 2
# 83.5 % -- 3
# 83.28 % -- 4
# 84.29 % -- 5
# 84.85 % -- 6
# 84.29 % -- 7
# 84.85 % -- 8
# 84.85 % -- 9
# 84.96 % -- 10
# 85.63 % -- 11
# 85.63 % -- 12
# 85.75 % -- 13
# 86.31 % -- 14
# 86.31 % -- 15
# 86.31 % -- 16
# 86.31 % -- 17
# 86.31 % -- 18
# 86.2 % -- 19

# %%
#k-nearest Neighbor KNN
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,Y_train)
Y_pred = knn.predict(X_test)
acc_knn = round(knn.score(X_train,Y_train) * 100,2)
print(acc_knn,'%')
# Out:
# 84.06 %

# %%
#Gaussian Naive Bayes
gaussian = GaussianNB()
gaussian.fit(X_train,Y_train)
Y_pred = gaussian.predict(X_test)
acc_gau = round(gaussian.score(X_train,Y_train) * 100,2)
print(acc_gau,'%')
# Out:
# 76.88 %

# %%
#Perceptron
perceptron = Perceptron()
perceptron.fit(X_train,Y_train)
Y_pred = perceptron.predict(X_test)
acc_perc = round(perceptron.score(X_train,Y_train)*100,2)
print(acc_perc,'%')
# Out:
# 79.35 %

# %%
#Linear SVC
linear_SVC = LinearSVC()
linear_SVC.fit(X_train,Y_train)
Y_pred = linear_SVC.predict(X_test)
acc_linsvc = round(linear_SVC.score(X_train,Y_train)*100,2)
print(acc_linsvc,'%')
# Out:
# 79.46 %
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "

# %%
#Stochastic Gradient Descent
sgd = SGDClassifier()
sgd.fit(X_train,Y_train)
Y_pred = sgd.predict(X_test)
acc_sgd = round(sgd.score(X_train,Y_train)*100,2)
print(acc_sgd,'%')
# Out:
# 74.75 %

# %%
#Decision Tree
dt = DecisionTreeClassifier()
dt.fit(X_train,Y_train)
Y_pred = dt.predict(X_test)
acc_dt = round(dt.score(X_train,Y_train)*100,2)
print(acc_dt,'%')
# Out:
# 86.64 %

# %%
#Random Forest
rf = RandomForestClassifier()
rf.fit(X_train,Y_train)
Y_pred = rf.predict(X_test)
acc_rf = round(rf.score(X_train,Y_train)*100,2)
print(acc_rf,'%')
# Out:
# 86.64 %

# %%
models = pd.DataFrame({'Model':
['SVM','Random Forest','KNN','Decision Tree',
'SGD','Linear SVC','Perceptron','Gaussian NB','Logistic Regression'],
'Scores':
[acc_svc,acc_rf,acc_knn,acc_dt,
acc_sgd,acc_linsvc,acc_perc,acc_gau,acc_log]}
)
models = models.sort_values(by='Scores',ascending=False).reset_index(drop=True)
models
# Out:
#                  Model  Scores
# 0        Random Forest   86.64
# 1        Decision Tree   86.64
# 2                  SVM   86.31
# 3                  KNN   84.06
# 4  Logistic Regression   81.37
# 5           Linear SVC   79.46
# 6           Perceptron   79.35
# 7          Gaussian NB   76.88
# 8                  SGD   74.75

# %%
submission = pd.DataFrame(
{'PassengerID':IDs, 
'Prediction':Y_pred
})
submission.to_csv('Submission.csv')
